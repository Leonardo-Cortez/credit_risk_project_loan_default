# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonardo-Cortez/credit_risk_project_loan_default/notebooks/blob/main/Credit_Risk_Project_Welcome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
